# %%
import pandas as pd # for working with dataframes
from os import listdir # for retrieving files from directory
from os.path import isfile, join # for retrieving files from directory

# %%
data_dir = "./modified_texts/" # set data directory
file_names = [f for f in listdir(data_dir) if isfile(join(data_dir, f))] # create a list of file names
file_names.remove('.DS_Store') # remove .DS_Store file
file_names.sort() # sort the list of file names
file_names # check list of file names

subchapter_names = [] # get subchapter names without ".txt"
for i in range(len(file_names)):
    subchapter_names.append(file_names[i][:-4])

# %%
df = pd.read_csv("./verify_subchapter.csv") # read in subchapter data
subchapter = df["subchapter"].str.split(";", expand=True) # split subchapter data
subchapter.fillna(0, inplace=True) # replace None and NaN with 0
nahuatl = df["nahuatl"] # isolate the nahuatl column
ID = df["ID"] # isolate the ID column
type = df["type"] # isolate the type column

# %%
# store information for search in lists
chapter_list = []
ID_list = []
type_list = []
name_list = []

for i in range(len(subchapter_names)): # for each subchapter

    chapter = subchapter_names[i] # get the current chapter name
    
    if chapter[0]=="0": # remove leading zeros from chapter name
        chapter = chapter[1:]
    
    matches = [] # save matches to chapter
    rows = [] # save rows/index in df to matches
    
    for j in range(len(subchapter)): # for each row 
        for k in range(len(subchapter.columns)): # for each column
    
            if chapter in str(subchapter.iloc[j,k]): # if subchapter found in entry, save to list
                matches.append(subchapter.iloc[j,k])
                rows.append(j)
    
    for l in range(len(matches)): # remove leading and trailing zeros from matches
        if matches[l][0] == " ":
            matches[l] = matches[l][1:]
        if matches[l][-1] == " ":
            matches[l] = matches[l][:-1]
    
    nahuatl_names = [] # find nahuatl names for each matched index
    types = [] # find type for each matched index
    IDs = [] # find IDs for each matched index
    for m in rows:
        nahuatl_names.append(nahuatl.iloc[m])
        types.append(type.iloc[m])
        IDs.append(ID.iloc[m])
    
    nahuatl_names = [x.lower() for x in nahuatl_names] # make all names lowercase
    
    for n in range(len(nahuatl_names)): # split by "; " if multiple names
        if ";" in nahuatl_names[n]:
            nahuatl_names[n] = nahuatl_names[n].split("; ")
    
    for o in range(len(matches)): # find alternate names in matches
        if " " in matches[o]:
            matches[o] = matches[o][:matches[o].rfind(" ")]
        else: # if no alternate, replace with nahuatl name
            matches[o] = nahuatl_names[o]
    
    names_list = [] # combine the names in matches and nahuatl_names together for each entry
    for p in range(len(matches)):
        
        temp_list = []
        if isinstance(matches[p], list):
            for q in matches[p]:
                temp_list.append(q)
        else:
            temp_list.append(matches[p])
    
        if isinstance(nahuatl_names[p], list):
            for q in nahuatl_names[p]:
                temp_list.append(q)
        else:
            temp_list.append(nahuatl_names[p])
    
        names_list.append(temp_list)
    
    unique_names = [] # find only unique names for each entry
    for r in range(len(names_list)):
        unique_names.append(list(set(names_list[r])))

    # store information to lists
    chapter_list.append(chapter)
    ID_list.append(IDs)
    type_list.append(types)
    name_list.append(unique_names)

# %%
print(len(chapter_list))
chapter_list
# Out:
# 98
# ['1a',
#  '1b',
#  '1c',
#  '1d',
#  '1e',
#  '1f',
#  '2a',
#  '2b',
#  '2c',
#  '2d',
#  '2e',
#  '2f',
#  '2g',
#  '2h',
#  '3a',
#  '4a',
#  '4b',
#  '4c',
#  '5a',
#  '5b',
#  '5c',
#  '5d',
#  '5e',
#  '5f',
#  '5g',
#  '5h',
#  '5i',
#  '6a',
#  '6b',
#  '6c',
#  '6d',
#  '6e',
#  '6f',
#  '6g',
#  '6h',
#  '6i',
#  '7a',
#  '7b',
#  '7c',
#  '7d',
#  '7e',
#  '7f',
#  '7g',
#  '7h',
#  '7i',
#  '7j',
#  '7k',
#  '7l',
#  '7m',
#  '7n',
#  '8a',
#  '8b',
#  '8c',
#  '8d',
#  '8e',
#  '8f',
#  '8g',
#  '8h',
#  '8i',
#  '8j',
#  '8k',
#  '8l',
#  '9a',
#  '9b',
#  '9c',
#  '9d',
#  '9e',
#  '9f',
#  '9g',
#  '9h',
#  '9i',
#  '9j',
#  '9k',
#  '9l',
#  '9m',
#  '9n',
#  '9o',
#  '9p',
#  '9q',
#  '10a',
#  '10b',
#  '10c',
#  '10d',
#  '10e',
#  '10f',
#  '10g',
#  '10h',
#  '10i',
#  '10j',
#  '10k',
#  '11a',
#  '11b',
#  '11c',
#  '11d',
#  '11e',
#  '12a',
#  '12b',
#  '13a']

# %%
print(len(ID_list))
ID_list
# Out:
# 98
# [[28,
#   49,
#   70,
#   70,
#   70,
#   123,
#   134,
#   143,
#   150,
#   208,
#   240,
#   266,
#   267,
#   268,
#   268,
#   269,
#   309,
#   310,
#   310,
#   310,
#   310],
#  [9, 92, 198, 215, 220, 268],
#  [25, 31, 36, 68, 107, 134, 195, 245, 266, 268, 268, 268, 270],
#  [16, 32, 56, 83, 103, 132, 163, 173, 176, 188],
#  [12, 90, 114, 177, 271],
#  [272],
#  [28, 81, 105, 117, 198, 202, 215, 220, 265, 279],
#  [48, 94, 110, 110, 118, 150, 194, 272, 273, 274],
#  [],
#  [],
#  [107],
#  [164, 172],
#  [76, 77, 221],
#  [],
#  [24,
#   112,
#   178,
#   179,
#   213,
#   215,
#   252,
#   257,
#   266,
#   268,
#   268,
#   272,
#   272,
#   272,
#   275,
#   295,
#   298,
#   300,
#   301],
#  [15, 236],
#  [39],
#  [228],
#  [],
#  [],
#  [124, 276, 277, 278],
#  [150, 180, 208, 268],
#  [43, 94, 150, 240, 279],
#  [41, 208],
#  [160, 171],
#  [28, 100, 100, 107, 196, 247, 277, 280],
#  [208, 215, 256],
#  [56, 116, 128, 215, 278],
#  [196, 237],
#  [122, 154, 168, 214],
#  [14, 28, 204],
#  [28, 170, 202],
#  [178, 257, 259],
#  [178, 257],
#  [235],
#  [54, 148, 252],
#  [214],
#  [19, 41, 45, 94, 128, 217, 233, 260, 272],
#  [126, 157, 266, 277],
#  [190, 279, 281],
#  [121, 178],
#  [215],
#  [184, 236],
#  [41, 184, 253, 258, 281],
#  [78, 82, 215, 247],
#  [101, 250],
#  [22, 24, 66, 192, 241],
#  [24, 32, 38, 130, 208, 209, 215],
#  [82, 104, 208, 261],
#  [97],
#  [96, 106, 165, 178, 247, 282],
#  [150, 165, 205],
#  [58, 72, 88, 101, 108, 218, 250],
#  [43, 58, 108, 173, 268],
#  [38, 54, 85, 160, 257, 258],
#  [18, 45, 131, 133, 147, 160, 204, 283],
#  [85, 150, 160, 252],
#  [53, 233, 247, 284],
#  [178, 285],
#  [3,
#   28,
#   28,
#   45,
#   54,
#   56,
#   62,
#   85,
#   131,
#   148,
#   149,
#   160,
#   178,
#   200,
#   242,
#   266,
#   268,
#   272,
#   278],
#  [9, 28, 45, 54, 105, 215, 217, 266, 268, 272],
#  [6,
#   17,
#   18,
#   21,
#   23,
#   24,
#   28,
#   30,
#   37,
#   42,
#   43,
#   47,
#   51,
#   56,
#   60,
#   94,
#   99,
#   113,
#   158,
#   181,
#   212,
#   266,
#   268,
#   272,
#   286,
#   287,
#   288,
#   289,
#   290,
#   291,
#   292,
#   293,
#   294],
#  [104, 215],
#  [7,
#   28,
#   38,
#   38,
#   38,
#   41,
#   68,
#   68,
#   104,
#   109,
#   160,
#   172,
#   208,
#   209,
#   215,
#   221,
#   222,
#   234,
#   254,
#   257,
#   257,
#   263,
#   281,
#   291,
#   292,
#   293,
#   295,
#   296,
#   297,
#   298,
#   299,
#   300,
#   301,
#   302,
#   303,
#   304],
#  [44, 79, 155],
#  [37, 42, 52, 57, 64, 89, 155, 196, 204, 211],
#  [1,
#   1,
#   38,
#   41,
#   54,
#   69,
#   74,
#   85,
#   103,
#   103,
#   172,
#   172,
#   180,
#   190,
#   200,
#   226,
#   240,
#   241,
#   257,
#   268,
#   272,
#   279,
#   291,
#   301,
#   305,
#   306,
#   307],
#  [17,
#   17,
#   18,
#   42,
#   68,
#   72,
#   91,
#   150,
#   208,
#   215,
#   220,
#   222,
#   247,
#   247,
#   266,
#   268,
#   291],
#  [14, 60, 85, 135, 141, 160, 187, 215],
#  [87, 130, 155, 155, 207, 215, 250, 257],
#  [14, 24, 213, 215],
#  [22, 198],
#  [129, 140, 166, 229, 246],
#  [10, 56, 85, 172, 193, 205, 227],
#  [24, 61, 71, 139, 147, 198, 203, 213, 215, 243],
#  [178, 198, 215, 220],
#  [22, 254, 257],
#  [28, 103, 127, 150, 168, 172],
#  [18, 38, 54, 56, 56, 56, 105, 128, 150, 200, 214, 215, 264, 278],
#  [4, 145, 145, 167, 214, 292],
#  [5, 28, 56, 135, 260, 308],
#  [],
#  [60, 62, 207, 225, 257],
#  [58, 62, 214, 266, 268, 272, 292, 298, 300],
#  [28, 48, 128, 182, 185, 189],
#  [93],
#  [309],
#  [54, 255],
#  [56, 161],
#  [16, 17, 58, 58, 84, 94, 99, 113, 224, 278],
#  [70, 70, 70, 123, 134, 143, 208, 240, 268, 309, 310, 310, 310, 310],
#  [9, 268],
#  [25, 31, 36, 68, 107, 134, 195, 245, 266, 268, 268, 268],
#  [32, 56, 132, 188],
#  [90, 114, 177],
#  [28, 81, 105, 117, 198, 202, 215, 220, 265, 279],
#  [150],
#  [24, 257, 268, 272, 272, 295, 298, 300, 301]]

# %%
print(len(type_list))
type_list
# Out:
# 98
# [['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'stone',
#   'stone',
#   'stone',
#   'stone',
#   'other',
#   'animal',
#   'animal',
#   'animal',
#   'animal'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'stone'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'stone',
#   'stone',
#   'stone',
#   'animal'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'animal'],
#  ['stone'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'other',
#   'bird'],
#  [],
#  [],
#  ['plant'],
#  ['plant', 'plant'],
#  ['plant', 'plant', 'plant'],
#  [],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'stone',
#   'stone',
#   'stone',
#   'stone',
#   'stone',
#   'stone',
#   'bird',
#   'bird',
#   'bird',
#   'bird'],
#  ['plant', 'plant'],
#  ['plant'],
#  ['plant'],
#  [],
#  [],
#  ['plant', 'stone', 'stone', 'other'],
#  ['plant', 'plant', 'plant', 'stone'],
#  ['plant', 'plant', 'plant', 'plant', 'stone'],
#  ['plant', 'plant'],
#  ['plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'stone', 'stone'],
#  ['plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'other'],
#  ['plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant'],
#  ['plant', 'plant'],
#  ['plant'],
#  ['plant', 'plant', 'plant'],
#  ['plant'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone'],
#  ['plant', 'plant', 'stone', 'stone'],
#  ['plant', 'stone', 'stone'],
#  ['plant', 'plant'],
#  ['plant'],
#  ['plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'stone'],
#  ['plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant'],
#  ['plant'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'stone'],
#  ['plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'stone'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'animal'],
#  ['plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant', 'bird'],
#  ['plant', 'other'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'stone',
#   'stone',
#   'other'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'stone',
#   'stone'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'stone',
#   'stone',
#   'animal',
#   'animal',
#   'animal',
#   'animal',
#   'stone',
#   'bird',
#   'bird',
#   'bird',
#   'animal'],
#  ['plant', 'plant'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'bird',
#   'bird',
#   'bird',
#   'bird',
#   'bird',
#   'bird',
#   'bird',
#   'bird',
#   'bird',
#   'bird',
#   'bird',
#   'bird',
#   'stone'],
#  ['plant', 'plant', 'plant'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'stone',
#   'stone',
#   'bird',
#   'bird',
#   'bird',
#   'bird',
#   'animal'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'stone',
#   'bird'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'plant'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant'],
#  ['plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'plant'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'other'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'bird'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'animal'],
#  [],
#  ['plant', 'plant', 'plant', 'plant', 'plant'],
#  ['plant',
#   'plant',
#   'plant',
#   'stone',
#   'stone',
#   'stone',
#   'bird',
#   'bird',
#   'bird'],
#  ['plant', 'plant', 'plant', 'plant', 'plant', 'plant'],
#  ['plant'],
#  ['other'],
#  ['plant', 'plant'],
#  ['plant', 'plant'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'other'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'other',
#   'animal',
#   'animal',
#   'animal',
#   'animal'],
#  ['plant', 'stone'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone',
#   'stone',
#   'stone',
#   'stone'],
#  ['plant', 'plant', 'plant', 'plant'],
#  ['plant', 'plant', 'plant'],
#  ['plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'plant',
#   'stone'],
#  ['plant'],
#  ['plant', 'plant', 'stone', 'stone', 'stone', 'bird', 'bird', 'bird', 'bird']]

# %%
print(len(name_list))
name_list
# Out:
# 98
# [[['eca-patli'],
#   ['iztac oco-xochitl'],
#   ['cihua-patli'],
#   ['cihua-patli'],
#   ['cihua-patli'],
#   ['nochtli'],
#   ['quauh-alahuac'],
#   ['a-huexotl', 'quetzal-ahuexotl'],
#   ['te-amoxtli'],
#   ['tlanextia', 'tlanextia xiuhtontli'],
#   ['xal-tomatl'],
#   ['tetlahuitl'],
#   ['iztac tlalli'],
#   ['eztetl'],
#   ['eztetl'],
#   ['te-mamatlatzin'],
#   ['octli'],
#   ['tlaquatzin'],
#   ['tlaquatzin'],
#   ['tlaquatzin'],
#   ['tlaquatzin']],
#  [['ahuiyac-xihuitl'],
#   ['chipauac', 'chipauac xihuitl'],
#   ['tlal-ahuehuetl'],
#   ['tlatlanquaye'],
#   ['tla-yapaloni'],
#   ['eztetl']],
#  [['ayo-nelhuatl'],
#   ['xiuh-elo-quilitl', 'xiuh-eloquilitl'],
#   ['iztac huitz-quahuitl'],
#   ['centzon-xochitl'],
#   ['malinalli'],
#   ['quauh-alahuac'],
#   ['tlaco-popotli', 'tlaco-popotl'],
#   ['xiuh-patli'],
#   ['tetlahuitl'],
#   ['eztetl'],
#   ['eztetl'],
#   ['eztetl'],
#   ['atzitzicuilotl']],
#  [['atoya-xocotl'],
#   ['elo-zacatl'],
#   ['quauh-yyauhtli'],
#   ['copal-quahuitl'],
#   ['huitz-quilitl'],
#   ['pozahualiz-xiuhtontli'],
#   ['tequam-maiti'],
#   ['tetzmi-xochitl'],
#   ['tezon-patli'],
#   ['totec-yxiuh']],
#  [['xiuh-amolli'],
#   ['chichiltic xiuhtontli'],
#   ['memeya xiuhtontli', 'memeya xiuhtontil', 'memeya-xihuitl'],
#   ['tohmiyo-xihuitl', 'tohmiyo xihuitl'],
#   ['avat-tecolotl']],
#  [['tlacal-huatzin']],
#  [['eca-patli', 'xiuh-ecapatli'],
#   ['coltotzin'],
#   ['huitzihtzil-xochitl', 'huitzitzil-xochitl'],
#   ['michi-huauhtli'],
#   ['tlal-ahuehuetl'],
#   ['tlal-mizquitl'],
#   ['tlatlanquaye'],
#   ['tla-yapaloni'],
#   ['a-camallo-tetl'],
#   ['a-camallo-tetl']],
#  [['oco-xochitl'],
#   ['huacal-xochitl'],
#   ['matlal-xochitl'],
#   ['matlal-xochitl', 'xoxouhqui matlal-xochitl'],
#   ['mizquitl'],
#   ['te-amoxtli'],
#   ['tlaco-izqui-xochitl'],
#   ['tlacal-huatzin'],
#   ['chilmolli'],
#   ['molo-tototl']],
#  [],
#  [],
#  [['malinalli']],
#  [['tequixqui-zacatl'], ['tetzmitl']],
#  [['cochiz-xihuitl'], ['huihuitzyo-cochiz-xihuitl'], ['tlazol-patli']],
#  [],
#  [['quetzal-ylin'],
#   ['maza-yelli'],
#   ['tolohua', 'tolova', 'tolohua xihuitl'],
#   ['tlapatl'],
#   ['tlaquilin'],
#   ['tlatlanquaye'],
#   ['xoxouhqui', 'xoxouhqui-patli', 'xoxouhca-patli'],
#   ['tonatiuh yxiuh'],
#   ['tetlahuitl'],
#   ['eztetl'],
#   ['eztetl'],
#   ['tlacal-huatzin'],
#   ['tlacal-huatzin'],
#   ['tlacal-huatzin'],
#   ['xoxouhqui chlalchihuitl'],
#   ['huitlalotl'],
#   ['xiuh-quechol-tototl'],
#   ['tlapal-tototl'],
#   ['noch-tototl']],
#  [['a-toch-ietl'], ['tzon-pilihuiz-xihuitl', 'tzonpilihuiz-xihuitl']],
#  [['iztac-patli']],
#  [['a-tzitzicaztli']],
#  [],
#  [],
#  [['teo-nochtli'],
#   ['iztac-quetzaliztli'],
#   ['chichiltic tapachtli'],
#   ['xochi-ocotzotl']],
#  [['te-amoxtli'],
#   ['tol-patlactli'],
#   ['tlanexti', 'tlanextia xiuhtontli'],
#   ['eztetl']],
#  [['tlaco-izqui-xochitl'],
#   ['huacal-xochitl'],
#   ['te-amoxtli'],
#   ['xal-tomatl'],
#   ['a-camallo-tetl']],
#  [['teo-iztaquilitl', 'teo-iztac-quilitl'],
#   ['tlanexti', 'tlanextia xiuhtontli']],
#  [['tepe chian', 'tepe-chian'], ['tetzmi-nopalli']],
#  [['eca-patli'],
#   ['huitz-colotli'],
#   ['huitz-colotli', 'huitz-colo-xochitl'],
#   ['malinalli'],
#   ['tlaco-xilo-xochitl'],
#   ['xiuhtontli'],
#   ['chichiltic tapachtli'],
#   ['teo-xihuitl']],
#  [['tlanextia xiuhtontli'], ['tlatlanquaye'], ['temamatlatzin']],
#  [['quauh-yyauhtli'],
#   ['mexix-quilitl'],
#   ['papalo-quilitl'],
#   ['tlatlanquaye'],
#   ['xochi-ocotzotl']],
#  [['tlaco-xilo-xochitl'], ['tzopelica-cococ']],
#  [['nocheztli'], ['tememetla', 'te-memetla'], ['te-xiyotl'], ['tlatlacotic']],
#  [['a-quahuitl'], ['eca-patli'], ['tlal-quequetzal']],
#  [['eca-patli'], ['tetezhuatic', 'te-tezhuatic'], ['tlal-mizquitl']],
#  [['tolohua', 'tolova', 'tolova-xihuitl', 'tolohua xihuitl'],
#   ['tonatiuh yxiuh'],
#   ['tecpatl']],
#  [['tolohua', 'tolova', 'tolohua xihuitl'], ['tonatiuh yxiuh']],
#  [['tzonpilihuiz-patli']],
#  [['iztauh-yattl', 'iztauyattl'],
#   ['quetzal-xoxouca-patli', 'xoxouhca patli'],
#   ['quetzal-xoxouhqui', 'xoxouhqui', 'xoxouhca-patli']],
#  [['tlatlacotic']],
#  [['ayauhtli'],
#   ['teo-iztaquilitl'],
#   ['itzcuinpatli', 'itzquin-patli'],
#   ['huacal-xochitl'],
#   ['papalo-quilitl'],
#   ['tlatlaolton'],
#   ['tzitzicton'],
#   ['tetlahuitl'],
#   ['tlacal-huatzin']],
#  [['nonochton azcapanixua', 'nonochton'],
#   ['teo-xihuitl'],
#   ['tetlahuitl'],
#   ['chichiltic tapachtli']],
#  [['tlaca-camotli'], ['a-camallo-tetl'], ['xiuh-tomolli']],
#  [['nexehuac'], ['tolohua', 'tolova', 'tolohua-xihuitl', 'tolohua xihuitl']],
#  [['tlatlanquaye']],
#  [['ahhuachcho tonatiuh-yxiuh', 'xiuhuitl tonalco-mochiva hahuachcho'],
#   ['tzon-pilihuiz-xihuitl', 'tzonpilihuiz-xihuitl']],
#  [['teo-iztaquilitl'],
#   ['xiuhuitl tonalco-mochiva hahuachcho', 'tonatiuh-yxiuh ahhuachcho'],
#   ['xoxouhqui-itzli'],
#   ['tonatiuh yxiuh'],
#   ['xiuh-tomolli']],
#  [['cococ-xihuitl'],
#   ['copaliyac-xiuhtontli'],
#   ['tlatlanquaye'],
#   ['xiuhtontli']],
#  [['huihuitz-mallotic'], ['ohua-xoxocoyolin']],
#  [['ylin'],
#   ['quetzal-ylin'],
#   ['capul-xihuitl'],
#   ['tlaco-amatl', 'tlacomatl'],
#   ['xal-xocotl', 'xa-xocotl']],
#  [['quetzal-ylin'],
#   ['elo-zacatl'],
#   ['iztac-oco-xochitl', 'iztac oco-xochitl'],
#   ['pizietl', 'piciyetl'],
#   ['tlanexti-xiuhtontli', 'tlanextia xiuhtontli'],
#   ['tlanextia quahuitl'],
#   ['tlatlanquaye']],
#  [['copaliyac-xiuhtontli'],
#   ['quauhtla huitz-quilitl'],
#   ['tlanexti-xiuhtontli', 'tlanextia xiuhtontli'],
#   ['chichic-xihuitl']],
#  [['huelic-patli']],
#  [['tlal-huaxin'],
#   ['macpal-xochitl'],
#   ['te-tzapotl'],
#   ['tolohua', 'tolova', 'tolohua-xihuitl', 'tolohua xihuitl'],
#   ['xiuhtontli'],
#   ['te-xoxoctli']],
#  [['te-amoxtli'],
#   ['te-tzapotl'],
#   ['tla-nen-popoloua xiuhtontli',
#    'xiuhtontli tlanen-popoloua',
#    'tla-nen-popoloua']],
#  [['yollo-xochitl'],
#   ['coanenepilli', 'cohuanene-pilli'],
#   ['chian'],
#   ['huihuitz-mallotic'],
#   ['mamaxtla'],
#   ['tlatlauhqui-amoxtli', 'tlatlauhqui amoxtli'],
#   ['ohua-xoxocoyolin']],
#  [['tlaco-izqui-xochitl'],
#   ['yollo-xochitl'],
#   ['mamaxtla'],
#   ['tetzmi-xochitl'],
#   ['eztetl']],
#  [['iztac-oco-xochitl', 'iztac oco-xochitl'],
#   ['iztauh-yatl', 'iztauyattl'],
#   ['coyo-xihuitl tlaztalehualtic', 'coyo-xihuitl'],
#   ['tepe-chian'],
#   ['tonatiuh yxiuh'],
#   ['tonatiuh yxiuh']],
#  [['ayauh-quahuitl'],
#   ['itzquin-patli'],
#   ['piltzinte-couh-xochitl', 'piltzin-tecouh-xochitl'],
#   ['quappo-quietl'],
#   ['quetzal-misquitl'],
#   ['tepe-chian'],
#   ['tlal-quequetzal', 'tlal-que quetzal'],
#   ['eca-cohuatl']],
#  [['coyo-xihuitl tlaztalehualtic', 'coyo-xihuitl'],
#   ['te-amoxtli'],
#   ['tepe-chian'],
#   ['xoxouhca-patli', 'xoxouhqui']],
#  [['te-xochitl yamanqui', 'yamanqui te-xochitl'],
#   ['tzitzicton'],
#   ['xiuhtontli'],
#   ['huacton']],
#  [['tolohua', 'tolova', 'tolohua-xihuitl', 'tolohua xihuitl'], ['hoxitl']],
#  [['a-chilli'],
#   ['eca-patli', 'xiuh-ecapatli'],
#   ['eca-patli'],
#   ['itzquin-patli'],
#   ['iztauh-yatl', 'iztauyattl'],
#   ['quauh-yyauhtli'],
#   ['cacaua-xochitl'],
#   ['coyo-xihuitl tlaztalehualtic', 'coyo-xihuitl'],
#   ['piltzinte-couh-xochitl', 'piltzin-tecouh-xochitl'],
#   ['quetzal-xoxouca-patli'],
#   ['tzotzotlani', 'quetzal-xoxouhca-patli tzotzotlani'],
#   ['tepe-chian'],
#   ['tolohua', 'tolova', 'tolohua-xihuitl', 'tolohua xihuitl'],
#   ['tlal-ecapatli'],
#   ['xe-xihuitl'],
#   ['tetlahuitl'],
#   ['eztetl'],
#   ['tlacal-huatzin'],
#   ['xochi-ocotzotl']],
#  [['ahuiyac-xihuitl'],
#   ['eca-patli', 'xiuh-ecapatli'],
#   ['itzcuin-patli', 'itzquin-patli'],
#   ['iztauh-yatl', 'iztauyattl'],
#   ['huitzihtzil-xochitl'],
#   ['tlatlanquaye'],
#   ['tlatlaolton'],
#   ['tetlahuitl'],
#   ['eztetl'],
#   ['tlacal-huatzin']],
#  [['ahuatl'],
#   ['a-xocotl'],
#   ['ayauh-quahuitl'],
#   ['a-ylin', 'a-illin'],
#   ['tepe-ylin'],
#   ['quetzal-ylin'],
#   ['eca-patli'],
#   ['elo-xochitl'],
#   ['huitz-quahuitl'],
#   ['izqui-xochitl'],
#   ['tlaco-izqui-xochitl'],
#   ['ocotl'],
#   ['oyametl'],
#   ['quauh-yyauhtli'],
#   ['cacalo-xochitl'],
#   ['huacal-xochitl'],
#   ['huey-nacaztli'],
#   ['meca-xochitl'],
#   ['te-papa-quilti-quahuitl', 'te-papaquilti quahuitl'],
#   ['tomaz-quitl', 'tomazquitl'],
#   ['tlapol-cacahuatl'],
#   ['tetlahuitl'],
#   ['eztetl'],
#   ['tlacal-huatzin'],
#   ['cuetlachtli'],
#   ['miztli'],
#   ['ocotochtli'],
#   ['tlaco-ocelotl'],
#   ['quetzal-iztli'],
#   ['huexo-canauhtli'],
#   ['hauctli'],
#   ['apopotli'],
#   ['coyotl']],
#  [['quauhtla huitz-quilitl'], ['tlatlan-quaye', 'tlatlanquaye']],
#  [['a-quitzli', 'ahquiztli'],
#   ['eca-patli', 'xiuh-ecapatli'],
#   ['iztac oco-xochitl', 'oco-xochitl'],
#   ['iztac oco-xochitl', 'oco-xochitl'],
#   ['iztac oco-xochitl', 'itzac-oco-xochitl'],
#   ['teo-iztaquilitl', 'teo-iztacuilitl'],
#   ['centzon-xochitl'],
#   ['centzon-xochitl'],
#   ['quauhtla huitz-quilitl', 'cuauhtla huita-quilitl'],
#   ['mamaxtla-nelhuatl'],
#   ['tepe-chian'],
#   ['tetzmitl'],
#   ['tlanextia xiuhtontli', 'tlanextia xihuitl'],
#   ['tlanextia quahuitl'],
#   ['tlatlanquaye'],
#   ['tlazol-patli'],
#   ['tlazol-teo-zacatl', 'tlazolco-zacatl'],
#   ['tzom-pachtin', 'tzon-pachtzin'],
#   ['zaca-matlalin'],
#   ['tonatiuh yxiuh'],
#   ['tonatiuh yxiuh'],
#   ['teco-xochiti-xihuitl'],
#   ['xiuh-tomolli'],
#   ['huexo-canauhtli'],
#   ['hauctli'],
#   ['apopotli'],
#   ['huitlalotl'],
#   ['aztatl'],
#   ['tlacahuilotl'],
#   ['xiuh-quechol-tototl'],
#   ['tototl'],
#   ['tlapal-tototl'],
#   ['noch-tototl'],
#   ['acatzanatl'],
#   ['zolin'],
#   ['texalli']],
#  [['quauh-izqui-xochitl'], ['colo-mecatl'], ['teo-amatl']],
#  [['huitz-quahuitl'],
#   ['izqui-xochitl'],
#   ['yamanqui patli'],
#   ['holli'],
#   ['capolla-xipehualli'],
#   ['texcal-amatl chichic', 'chichic texcal-amatl'],
#   ['teo-amatl'],
#   ['tlaco-xilo-xochitl'],
#   ['tlal-quequetzal'],
#   ['tlapal-achiyotl']],
#  [['acacapac-quilitl', 'aca-capac-quilitl'],
#   ['acapac-quilitl', 'aca-capac-quilitl'],
#   ['iztac-oco-xochitl', 'iztac oco-xochitl'],
#   ['teo-iztaquilitl'],
#   ['iztauhyauh', 'iztauyattl'],
#   ['centzon-oco-xochitl'],
#   ['cohua-xochitl'],
#   ['coyo-xihuitl tlaztalehualtic', 'coyo-xihuitl'],
#   ['huitz-quilitl'],
#   ['huitz-quilitl'],
#   ['tetzmitl'],
#   ['tetzmitl'],
#   ['tol-patlactli'],
#   ['tlaca-camotli'],
#   ['tlal-ecapatli'],
#   ['tzayanal-quilitl'],
#   ['xal-tomatl'],
#   ['xal-xocotl', 'xa-xocotl'],
#   ['tonatiuh yxiuh', 'tonatiuh-yxiuh'],
#   ['eztetl'],
#   ['tlacal-huatzin'],
#   ['a-camallo-tetl'],
#   ['huexo-canauhtli'],
#   ['noch-tototl'],
#   ['huitzitzilin'],
#   ['cocotli'],
#   ['pezotli']],
#  [['a-xocotl'],
#   ['a-xocotl'],
#   ['ayauh-quahuitl'],
#   ['izqui-xochitl'],
#   ['centzon-xochitl'],
#   ['coanenepilli'],
#   ['chicom-acatl'],
#   ['te-amoxtli'],
#   ['tlanexti xihuitl', 'tlanextia xiuhtontli'],
#   ['tlatlanquaye'],
#   ['tlayapaloni', 'tla-yapaloni'],
#   ['tlazol-teo-zacatl'],
#   ['xiuhtontli'],
#   ['xiuhtontli'],
#   ['tetlahuitl'],
#   ['eztetl'],
#   ['huexo-canauhtli']],
#  [['a-quahuitl'],
#   ['cacalo-xochitl'],
#   ['coyo-xihuitl tlaztalehualtic', 'coyo-xihuitl'],
#   ['quauh-yayahual'],
#   ['quauh-xiyotl'],
#   ['tepe-chian'],
#   ['Topozan', 'tópozan'],
#   ['tlatlanquaye']],
#  [['cuecuetz-patli'],
#   ['piciyetl'],
#   ['teo-amatl'],
#   ['teo-amatl'],
#   ['tlanextia-yxiuh'],
#   ['tlatlanquaye'],
#   ['ohua-xoxocoyolin'],
#   ['tonatiuh yxiuh', 'tonatiuh-yxiuh']],
#  [['a-quahuitl'], ['quetzal-ylin'], ['tlaquilin'], ['tlatlanquaye']],
#  [['ylin'], ['tlal-ahuehuetl']],
#  [['patlahuac tzitzicaztli'],
#   ['quauh-tzitzicaztli'],
#   ['te-tzitzicaztli'],
#   ['colo-tzitzicaztli'],
#   ['xiuh-tlemaitl']],
#  [['ahuiyac tlatlanquaye', 'ahhuiyac-tlatlanquaye'],
#   ['quauh-yyauhtli'],
#   ['coyo-xihuitl tlaztalehualtic', 'coyo-xihuitl'],
#   ['tetzmitl'],
#   ['tlaco-ecapatli', 'tlaco-eca-patli'],
#   ['tlanen-popoloa', 'tla-nen-popoloua xiuhtontli', 'tla-nen-popoloua'],
#   ['tzihuac-copalli']],
#  [['quetzal-ylin'],
#   ['tlal-cacapol'],
#   ['cimatl'],
#   ['quauh-patli'],
#   ['quetzal-mizquitl', 'quetzal-misquitl'],
#   ['tlal-ahuehuetl'],
#   ['tlal-patli'],
#   ['tlaquilin'],
#   ['tlatlanquaye'],
#   ['xilo-xochitl']],
#  [['tolohua', 'tolova', 'tolohua-xihuitl', 'tolohua xihuitl'],
#   ['tlal-ahuehuetl'],
#   ['tlatlanquaye'],
#   ['tla-yapaloni']],
#  [['ylin'], ['zaca-matlalin'], ['tonatiuh yxiuh', 'tonatiuh-yxiuh']],
#  [['eca-patli'],
#   ['huitz-quilitl'],
#   ['nopalli', 'nohpalli'],
#   ['te-amoxtli'],
#   ['te-xiyotl'],
#   ['tetzmitl']],
#  [['ayauh-quahuitl'],
#   ['iztac oco-xochitl', 'itzac-oco-xochitl'],
#   ['iztauh-yatl', 'iztauyattl'],
#   ['quauh-yyauhtli'],
#   ['quauh-yyauhtli'],
#   ['quauh-yyauhtli'],
#   ['huitzihtzil-xochitl', 'huitbitzil xochitil'],
#   ['papalo-quilitl'],
#   ['te-amoxtli'],
#   ['tlal-ecapatli'],
#   ['tlatlacotic'],
#   ['tlatlanquaye'],
#   ['tepaquilti quahuitl'],
#   ['xochi-ocotzotl']],
#  [['acoco-xihuitl', 'acocotli'],
#   ['quetzal-atzonyatl'],
#   ['quetzal-atzonyatl', 'quetzal-atzo-yatl'],
#   ['te-tzilin', 'te-tzitzilin'],
#   ['tlatlacotic'],
#   ['hauctli']],
#  [['acxoyatl'],
#   ['eca-patli', 'xiuh-ecapatli'],
#   ['quauh-yyauhtli'],
#   ['quauh-yayahual'],
#   ['tetlahuitl'],
#   ['acuecueyalotl']],
#  [],
#  [['cacalo-xochitl'],
#   ['cacaua-xochitl'],
#   ['tlanextia-yxiuh'],
#   ['tzacouh-xochitl'],
#   ['tonatiuh yxiuh', 'tonatiuh-yxiuh']],
#  [['yollo-xochitl'],
#   ['cacaua-xochitl'],
#   ['tlatlacotic'],
#   ['tetlahuitl'],
#   ['eztetl'],
#   ['tlacal-huatzin'],
#   ['hauctli'],
#   ['xiuh-quechol-tototl'],
#   ['tlapal-tototl']],
#  [['eca-patli', 'xiuh-ecapatli'],
#   ['oco-xochitl'],
#   ['papalo-quilitl'],
#   ['tonaca-xochitl'],
#   ['ayauh-tonan-yxiuh'],
#   ['totoloctzin']],
#  [['chiyava xihuitl']],
#  [['octli']],
#  [['iztauhyatl', 'iztauyattl'], ['zozoyatic']],
#  [['yyauhtli', 'quauh-yyauhtli'],
#   ['tepe-papalo-quilitl', 'tepepapalo quilitl']],
#  [['atoya-xocotl'],
#   ['a-xocotl'],
#   ['yollo-xochitl'],
#   ['yollo-xochitl'],
#   ['copal-xocotl'],
#   ['huacal-xochitl'],
#   ['huey-nacaztli'],
#   ['meca-xochitl'],
#   ['tlil-xochitl'],
#   ['xochi-ocotzotl']],
#  [['cihua-patli'],
#   ['cihua-patli'],
#   ['cihua-patli'],
#   ['nochtli'],
#   ['quauh-alahuac'],
#   ['a-huexotl', 'quetzal-ahuexotl'],
#   ['tlanextia', 'tlanextia xiuhtontli'],
#   ['xal-tomatl'],
#   ['eztetl'],
#   ['octli'],
#   ['tlaquatzin'],
#   ['tlaquatzin'],
#   ['tlaquatzin'],
#   ['tlaquatzin']],
#  [['ahuiyac-xihuitl'], ['eztetl']],
#  [['ayo-nelhuatl'],
#   ['xiuh-elo-quilitl', 'xiuh-eloquilitl'],
#   ['iztac huitz-quahuitl'],
#   ['centzon-xochitl'],
#   ['malinalli'],
#   ['quauh-alahuac'],
#   ['tlaco-popotli', 'tlaco-popotl'],
#   ['xiuh-patli'],
#   ['tetlahuitl'],
#   ['eztetl'],
#   ['eztetl'],
#   ['eztetl']],
#  [['elo-zacatl'],
#   ['quauh-yyauhtli'],
#   ['pozahualiz-xiuhtontli'],
#   ['totec-yxiuh']],
#  [['chichiltic xiuhtontli'],
#   ['memeya xiuhtontli', 'memeya xiuhtontil', 'memeya-xihuitl'],
#   ['tohmiyo-xihuitl', 'tohmiyo xihuitl']],
#  [['eca-patli', 'xiuh-ecapatli'],
#   ['coltotzin'],
#   ['huitzihtzil-xochitl', 'huitzitzil-xochitl'],
#   ['michi-huauhtli'],
#   ['tlal-ahuehuetl'],
#   ['tlal-mizquitl'],
#   ['tlatlanquaye'],
#   ['tla-yapaloni'],
#   ['a-camallo-tetl'],
#   ['a-camallo-tetl']],
#  [['te-amoxtli']],
#  [['quetzal-ylin'],
#   ['tonatiuh yxiuh'],
#   ['eztetl'],
#   ['tlacal-huatzin'],
#   ['tlacal-huatzin'],
#   ['huitlalotl'],
#   ['xiuh-quechol-tototl'],
#   ['tlapal-tototl'],
#   ['noch-tototl']]]
